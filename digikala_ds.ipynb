# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import datasets
orders_dataset_raw = pd.read_csv("./digikala_dataset/orders.csv")
orders_dataset_raw.head(4)
# Out:
#    ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 0   2714054       469662    21386  2015-10-15 08:50:56.000
# 1  11104039      3063877   248497  2018-02-11 00:29:26.000
# 2   4228130      3184893    50144  2016-06-14 00:30:08.000
# 3  22225624      6888562    70208  2018-09-03 14:37:19.000
#
#    Amount_Gross_Order city_name_fa  Quantity_item
# 0            597982.0   محمود آباد            1.0
# 1            980000.0       خرمدره            1.0
# 2            229358.0         قرچک            1.0
# 3             16514.0           قم            1.0

# %%
orders_dataset_raw = orders_dataset_raw.sort_values(by='ID_Item')
orders_dataset_raw.head(20)
# Out:
#         ID_Order  ID_Customer  ID_Item    DateTime_CartFinalize  \
# 129780   1284578       684095       76  2014-06-29 10:35:43.000
# 197157   1248083       930184       82  2014-05-28 17:52:21.000
# 27606    1480539       806950       86  2014-10-27 10:58:42.000
# 161453   1522898      1262930       86  2014-11-19 09:19:09.000
# 199699   1446278       612842       86  2014-10-06 23:14:52.000
# 118046   1187653       526502       86  2014-04-06 13:17:06.000
# 191230   1462521      1213504       86  2014-10-15 20:21:07.000
# 183684   4445049      2925745       89  2016-07-12 09:20:10.000
# 93043    1695177      1329294       89  2015-01-27 17:25:04.000
# 189281   1372904      1057783       89  2014-08-24 20:15:34.000
# 77816    1736157       862686       89  2015-02-11 12:01:06.000
# 79116    1189718       763974       91  2014-04-08 20:33:00.000
# 124602   1244369       874357       91  2014-05-24 22:16:09.000
# 177550   7451542       714267       91  2017-06-01 00:03:36.000
# ...

# %%
orders_dataset_raw["ID_Item"].value_counts()
# Out:
# 294942     481
# 36871      367
# 51778      288
# 45121      259
# 8289       233
#           ...
# 1355224      1
# 42457        1
# 126871       1
# 351718       1
# 40877        1
# Name: ID_Item, Length: 95232, dtype: int64

# %%
buy_hist_dataset_raw = pd.read_csv("./digikala_dataset/tarikhche kharid.csv")
buy_hist_dataset_raw.head(4)
# Out:
#          id  product_variant_id  selling_price  rrp_price base_price  \
# 0  18752043             1977385         850000     850000         \N
# 1  18752022             1977380       12550000   12550000         \N
# 2  18752046             1977380       12500000   12500000         \N
# 3  18751982             1977374         310000     310000         \N
#
#   buy_price  order_limit start_at end_at tags  show_in_price_history  active  \
# 0        \N            1       \N     \N   \N                      1       1
# 1        \N            2       \N     \N   \N                      1       0
# 2        \N            2       \N     \N   \N                      1       1
# 3        \N            2       \N     \N   \N                      1       0
#
#             created_at  product_id  marketplace_seller_id
# 0  2018-11-26 18:59:52      667969                   2962
# 1  2018-11-26 18:59:31      150144                  78525
# 2  2018-11-26 18:59:55      150144                  78525
# ...

# %%
buy_hist_dataset_raw["product_id"].value_counts()
# Out:
# 138830    81109
# 138847    57552
# 349909    52834
# 108167    49572
# 163470    49417
#           ...
# 76309         1
# 146302        1
# 313453        1
# 601377        1
# 147771        1
# Name: product_id, Length: 23721, dtype: int64

# %%
buy_hist_dataset_raw["product_variant_id"].value_counts()
# Out:
# 1396744    76003
# 1283649    57383
# 1283657    52204
# 1298439    49508
# 1348814    32451
#            ...
# 1278029        1
# 1863016        1
# 1974163        1
# 1972114        1
# 1877624        1
# Name: product_variant_id, Length: 99993, dtype: int64
